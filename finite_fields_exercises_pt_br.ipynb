# %% [markdown]
# # Exercícios: Corpos Finitos em Python
#
# Este notebook acompanha o post **Corpos finitos: a matemática modular por trás do Bitcoin**.
#
# A classe `FieldElement` já está pronta em `field_element.py`. Você só implementa as funções indicadas em cada exercício. Os testes ficam nos arquivos `.py` ao lado deste notebook (como no livro *Programming Bitcoin*).

# %%
############## EXECUTE ESTA CÉLULA PRIMEIRO ###################

from importlib import reload

from helper import run
import field_element
import finite_fields

# %% [markdown]
# ### Exercício 1
#
# Simule a analogia do relógio: `(hour + delta) % modulo`.
#
# Faça passar: `finite_fields.py:FiniteFieldsTest:test_clock_add`

# %%
# Exercício 1

reload(finite_fields)

def clock_add(hour, delta, modulo=12):
    # implemente aqui
    pass

finite_fields.clock_add = clock_add

run(finite_fields.FiniteFieldsTest("test_clock_add"))

# %% [markdown]
# ### Exercício 2
#
# Dois elementos são iguais quando têm o mesmo `num` **e** o mesmo `prime`.
#
# Faça passar: `field_element.py:FieldElementTest:test_eq` e `test_ne`

# %%
# Exercício 2

reload(field_element)

def __eq__(self, other):
    # implemente aqui
    pass

def __ne__(self, other):
    # implemente aqui
    pass

field_element.FieldElement.__eq__ = __eq__
field_element.FieldElement.__ne__ = __ne__

run(field_element.FieldElementTest("test_eq"))
run(field_element.FieldElementTest("test_ne"))

# %% [markdown]
# ### Exercício 3
#
# Rejeite valores fora do intervalo `[0, prime - 1]`.
#
# Faça passar: `field_element.py:FieldElementTest:test_init`

# %%
# Exercício 3

reload(field_element)

def __init__(self, num, prime):
    # implemente aqui
    pass

field_element.FieldElement.__init__ = __init__

run(field_element.FieldElementTest("test_init"))

# %% [markdown]
# ### Exercício 4
#
# Some os números e aplique `% prime`.
#
# Faça passar: `field_element.py:FieldElementTest:test_add`

# %%
# Exercício 4

reload(field_element)

def __add__(self, other):
    # implemente aqui
    pass

field_element.FieldElement.__add__ = __add__

run(field_element.FieldElementTest("test_add"))

# %% [markdown]
# ### Exercício 5
#
# A subtração deve funcionar mesmo quando o resultado seria negativo.
#
# Faça passar: `field_element.py:FieldElementTest:test_sub`

# %%
# Exercício 5

reload(field_element)

def __sub__(self, other):
    # implemente aqui
    pass

field_element.FieldElement.__sub__ = __sub__

run(field_element.FieldElementTest("test_sub"))

# %% [markdown]
# ### Exercício 6
#
# Multiplique os números e aplique `% prime`.
#
# Faça passar: `field_element.py:FieldElementTest:test_mul`

# %%
# Exercício 6

reload(field_element)

def __mul__(self, other):
    # implemente aqui
    pass

field_element.FieldElement.__mul__ = __mul__

run(field_element.FieldElementTest("test_mul"))

# %% [markdown]
# ### Exercício 7
#
# Use `pow` para expoentes positivos. Para negativos, use o Pequeno Teorema de Fermat.
#
# Faça passar: `field_element.py:FieldElementTest:test_pow`

# %%
# Exercício 7

reload(field_element)

def __pow__(self, exponent):
    # implemente aqui
    pass

field_element.FieldElement.__pow__ = __pow__

run(field_element.FieldElementTest("test_pow"))

# %% [markdown]
# ### Exercício 8
#
# Dividir por `b` é multiplicar pelo inverso multiplicativo de `b`.
#
# Faça passar: `field_element.py:FieldElementTest:test_div`

# %%
# Exercício 8

reload(field_element)

def __truediv__(self, other):
    # implemente aqui
    pass

field_element.FieldElement.__truediv__ = __truediv__

run(field_element.FieldElementTest("test_div"))

# %% [markdown]
# ### Exercício 9
#
# Retorne o inverso multiplicativo de `n` em Fₚ usando Fermat.
#
# Faça passar: `finite_fields.py:FiniteFieldsTest:test_multiplicative_inverse`

# %%
# Exercício 9

reload(finite_fields)

def multiplicative_inverse(n, prime):
    # implemente aqui
    pass

finite_fields.multiplicative_inverse = multiplicative_inverse

run(finite_fields.FiniteFieldsTest("test_multiplicative_inverse"))

# %% [markdown]
# ### Exercício 10
#
# Implemente `assert_fermat_holds(prime)` verificando `pow(n, prime - 1, prime) == 1` para todo `n` de `1` até `prime - 1`.
#
# Faça passar: `finite_fields.py:FiniteFieldsTest:test_fermat`

# %%
# Exercício 10

reload(finite_fields)

def assert_fermat_holds(prime):
    # implemente aqui
    pass

finite_fields.assert_fermat_holds = assert_fermat_holds

run(finite_fields.FiniteFieldsTest("test_fermat"))
