# %% [markdown]
# # Exercises: Finite Fields in Python
#
# This notebook accompanies the blog post on **finite fields and modular math behind Bitcoin**.
#
# The `FieldElement` class is already set up in `field_element.py`. You only implement the functions for each exercise. Tests live in the `.py` files next to this notebook.

# %%
############## RUN THIS CELL FIRST ###################

from importlib import reload

from helper import run
import field_element
import finite_fields

# %% [markdown]
# ### Exercise 1
#
# Simulate the clock analogy: `(hour + delta) % modulo`.
#
# Make this pass: `finite_fields.py:FiniteFieldsTest:test_clock_add`

# %%
# Exercise 1

reload(finite_fields)

def clock_add(hour, delta, modulo=12):
    # implement here
    pass

finite_fields.clock_add = clock_add

run(finite_fields.FiniteFieldsTest("test_clock_add"))

# %% [markdown]
# ### Exercise 2
#
# Two elements are equal when they share the same `num` **and** the same `prime`.
#
# Make this pass: `field_element.py:FieldElementTest:test_eq` and `test_ne`

# %%
# Exercise 2

reload(field_element)

def __eq__(self, other):
    # implement here
    pass

def __ne__(self, other):
    # implement here
    pass

field_element.FieldElement.__eq__ = __eq__
field_element.FieldElement.__ne__ = __ne__

run(field_element.FieldElementTest("test_eq"))
run(field_element.FieldElementTest("test_ne"))

# %% [markdown]
# ### Exercise 3
#
# Reject values outside `[0, prime - 1]`.
#
# Make this pass: `field_element.py:FieldElementTest:test_init`

# %%
# Exercise 3

reload(field_element)

def __init__(self, num, prime):
    # implement here
    pass

field_element.FieldElement.__init__ = __init__

run(field_element.FieldElementTest("test_init"))

# %% [markdown]
# ### Exercise 4
#
# Add the numbers and apply `% prime`.
#
# Make this pass: `field_element.py:FieldElementTest:test_add`

# %%
# Exercise 4

reload(field_element)

def __add__(self, other):
    # implement here
    pass

field_element.FieldElement.__add__ = __add__

run(field_element.FieldElementTest("test_add"))

# %% [markdown]
# ### Exercise 5
#
# Subtraction must work even when the result would be negative.
#
# Make this pass: `field_element.py:FieldElementTest:test_sub`

# %%
# Exercise 5

reload(field_element)

def __sub__(self, other):
    # implement here
    pass

field_element.FieldElement.__sub__ = __sub__

run(field_element.FieldElementTest("test_sub"))

# %% [markdown]
# ### Exercise 6
#
# Multiply the numbers and apply `% prime`.
#
# Make this pass: `field_element.py:FieldElementTest:test_mul`

# %%
# Exercise 6

reload(field_element)

def __mul__(self, other):
    # implement here
    pass

field_element.FieldElement.__mul__ = __mul__

run(field_element.FieldElementTest("test_mul"))

# %% [markdown]
# ### Exercise 7
#
# Use `pow` for positive exponents. For negative ones, use Fermat's Little Theorem.
#
# Make this pass: `field_element.py:FieldElementTest:test_pow`

# %%
# Exercise 7

reload(field_element)

def __pow__(self, exponent):
    # implement here
    pass

field_element.FieldElement.__pow__ = __pow__

run(field_element.FieldElementTest("test_pow"))

# %% [markdown]
# ### Exercise 8
#
# Dividing by `b` means multiplying by the multiplicative inverse of `b`.
#
# Make this pass: `field_element.py:FieldElementTest:test_div`

# %%
# Exercise 8

reload(field_element)

def __truediv__(self, other):
    # implement here
    pass

field_element.FieldElement.__truediv__ = __truediv__

run(field_element.FieldElementTest("test_div"))

# %% [markdown]
# ### Exercise 9
#
# Return the multiplicative inverse of `n` in Fₚ using Fermat.
#
# Make this pass: `finite_fields.py:FiniteFieldsTest:test_multiplicative_inverse`

# %%
# Exercise 9

reload(finite_fields)

def multiplicative_inverse(n, prime):
    # implement here
    pass

finite_fields.multiplicative_inverse = multiplicative_inverse

run(finite_fields.FiniteFieldsTest("test_multiplicative_inverse"))

# %% [markdown]
# ### Exercise 10
#
# Implement `assert_fermat_holds(prime)` by checking `pow(n, prime - 1, prime) == 1` for every `n` from `1` to `prime - 1`.
#
# Make this pass: `finite_fields.py:FiniteFieldsTest:test_fermat`

# %%
# Exercise 10

reload(finite_fields)

def assert_fermat_holds(prime):
    # implement here
    pass

finite_fields.assert_fermat_holds = assert_fermat_holds

run(finite_fields.FiniteFieldsTest("test_fermat"))
